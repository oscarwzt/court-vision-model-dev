# %%
import ray
from ray import tune
from ray.tune.schedulers import HyperBandScheduler
from ray.tune import CLIReporter
from ray.train import RunConfig
import torch
import torchvision.models as models
import torch.optim as optim
import torch.nn as nn
from utils import * 
from training_utils import *

data_full_path = "/scratch/zw2688/Court_Vision_Model_Dev/data/classification_dataset_groupby_env_split"      
  
def train_resnet(config):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
    model.fc = nn.Linear(model.fc.in_features, 1)
    model.to(device)
    
    if config['normalize']:
        normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                                             std=[0.229, 0.224, 0.225])
    else:
        normalize = None
    train_loader, valid_loader, _ = get_data_loaders(config["batch_size"], config["img_size"],  data_full_path, normalize)
    
    if config["optimizer"] == "sgd":
        optimizer = optim.SGD(model.parameters(), lr=config["lr"], momentum=config['momentum'], nesterov=config["nestrov"])
    elif config["optimizer"] == "adam":
        optimizer = optim.Adam(model.parameters(), lr=config["lr"])
    else:
        optimizer = optim.RMSprop(model.parameters(), lr=config["lr"])
    
    # optimizer = optim.SGD(model.parameters(), lr=config["lr"], momentum=config['momentum'], nesterov=config["nestrov"])
    
    criterion = nn.BCEWithLogitsLoss()
    while True:
        train_epoch(model, optimizer, criterion, train_loader, device)
        _, test_accuracy = test(model, criterion, valid_loader, device)
        ray.train.report(metrics = {"accuracy": test_accuracy})

# %%
batch_sizes = [64, 128, 256]
img_sizes = [224, 112, 96]
optimizers = ["rmsprop"]

# hyperband
hyperband_scheduler = HyperBandScheduler(
    time_attr='training_iteration',
    metric='accuracy',
    mode='max',
    max_t=120,
    reduction_factor=3
    )

hyperband_analysis = tune.run(
    train_resnet,
    name="tuning_cls_resnet18_augmented_rmsprop",
    stop={
        "accuracy": 0.93,
        "training_iteration": 100
    },
    resources_per_trial={
        "gpu": 0.1,
    },
    config = {
        "lr": tune.loguniform(8e-5, 5e-3),
        "batch_size": tune.grid_search(batch_sizes),
        "optimizer": tune.grid_search(optimizers),
        "img_size": tune.grid_search(img_sizes),
        #"nestrov": tune.grid_search([True, False]),
        #"momentum": tune.uniform(0.6, 0.95),
        "normalize": tune.grid_search([True, False]),
    },
    scheduler=hyperband_scheduler,
    num_samples=20,
    storage_path = "/scratch/zw2688/Court_Vision_Model_Dev/tune_results",
)
# Out:
# 2024-01-05 11:02:07,674	INFO worker.py:1664 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2024-01-05 11:02:09,691	INFO tune.py:220 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2024-01-05 11:02:09,694	INFO tune.py:586 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-01-05 12:31:04</td></tr>
# <tr><td>Running for: </td><td>01:28:54.73        </td></tr>
# <tr><td>Memory:      </td><td>113.1/377.3 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=199 total_brackets=15<br>Round #0:<br>  Bracket(Max Size (n)=5, Milestone (r)=120, completed=30.8%): {RUNNING: 2, TERMINATED: 3} <br>  Bracket(Max Size (n)=8, Milestone (r)=40, completed=42.3%): {PAUSED: 5, RUNNING: 2, TERMINATED: 1} <br>  Bracket(Max Size (n)=5, Milestone (r)=39, completed=31.0%): {PAUSED: 1, RUNNING: 3, TERMINATED: 11} <br>  Bracket(Max Size (n)=12, Milestone (r)=12, completed=30.0%): {PAUSED: 7, RUNNING: 3, TERMINATED: 24} <br>  Bracket(Max Size (n)=9, Milestone (r)=9, completed=32.3%): {PAUSED: 5, PENDING: 1, RUNNING: 3, TERMINATED: 72} <br>Round #1:<br>  Bracket(Max Size (n)=5, Milestone (r)=120, completed=100.0%): {TERMINATED: 5} <br>  Bracket(Max Size (n)=8, Milestone (r)=40, completed=41.6%): {PAUSED: 5, RUNNING: 2, TERMINATED: 1} <br>  Bracket(Max Size (n)=5, Milestone (r)=39, completed=28.8%): {PAUSED: 5, TERMINATED: 10} <br>  Bracket(Max Size (n)=12, Milestone (r)=12, completed=21.9%): {PAUSED: 8, RUNNING: 4, TERMINATED: 22} <br>  Bracket(Max Size (n)=27, Milestone (r)=3, completed=22.0%): {PAUSED: 25, RUNNING: 2, TERMINATED: 54} <br>Round #2:<br>  Bracket(Max Size (n)=5, Milestone (r)=120, completed=42.0%): {RUNNING: 2, TERMINATED: 3} <br>  Bracket(Max Size (n)=8, Milestone (r)=40, completed=45.5%): {PAUSED: 4, RUNNING: 4} <br>  Bracket(Max Size (n)=15, Milestone (r)=13, completed=28.0%): {PAUSED: 11, RUNNING: 3, TERMINATED: 1} <br>  Bracket(Max Size (n)=12, Milestone (r)=12, completed=20.6%): {PAUSED: 12, TERMINATED: 22} <br>  Bracket(Max Size (n)=27, Milestone (r)=3, completed=3.5%): {PAUSED: 12} <br>Logical resource usage: 0/48 CPUs, 3.1000000000000014/4 GPUs (0.0/1.0 accelerator_type:RTX)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 340 more trials not shown (23 RUNNING, 93 PAUSED, 222 TERMINATED)
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name              </th><th>status    </th><th>loc                </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  img_size</th><th style="text-align: right;">         lr</th><th>normalize  </th><th>optimizer  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_resnet_c80af_00002</td><td>RUNNING   </td><td>10.32.35.157:500800</td><td style="text-align: right;">         256</td><td style="text-align: right;">       224</td><td style="text-align: right;">0.000689031</td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">    15</td><td style="text-align: right;">       5203.87  </td><td style="text-align: right;">  0.509091</td></tr>
# <tr><td>train_resnet_c80af_00004</td><td>RUNNING   </td><td>10.32.35.157:500821</td><td style="text-align: right;">         128</td><td style="text-align: right;">       112</td><td style="text-align: right;">0.00013357 </td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">    60</td><td style="text-align: right;">       5284.6   </td><td style="text-align: right;">  0.869091</td></tr>
# <tr><td>train_resnet_c80af_00010</td><td>RUNNING   </td><td>10.32.35.157:500940</td><td style="text-align: right;">         128</td><td style="text-align: right;">       224</td><td style="text-align: right;">0.000854492</td><td>False      </td><td>rmsprop    </td><td style="text-align: right;">    17</td><td style="text-align: right;">       5175.56  </td><td style="text-align: right;">  0.56    </td></tr>
# <tr><td>train_resnet_c80af_00011</td><td>RUNNING   </td><td>10.32.35.157:500942</td><td style="text-align: right;">         256</td><td style="text-align: right;">       224</td><td style="text-align: right;">0.00116204 </td><td>False      </td><td>rmsprop    </td><td style="text-align: right;">    16</td><td style="text-align: right;">       5090.61  </td><td style="text-align: right;">  0.643636</td></tr>
# <tr><td>train_resnet_c80af_00017</td><td>RUNNING   </td><td>10.32.35.157:541896</td><td style="text-align: right;">         256</td><td style="text-align: right;">        96</td><td style="text-align: right;">0.000177545</td><td>False      </td><td>rmsprop    </td><td style="text-align: right;">     9</td><td style="text-align: right;">        557.5   </td><td style="text-align: right;">  0.883636</td></tr>
# <tr><td>train_resnet_c80af_00020</td><td>RUNNING   </td><td>10.32.35.157:542073</td><td style="text-align: right;">         256</td><td style="text-align: right;">       224</td><td style="text-align: right;">0.000116616</td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">     1</td><td style="text-align: right;">        314.572 </td><td style="text-align: right;">  0.498182</td></tr>
# <tr><td>train_resnet_c80af_00026</td><td>RUNNING   </td><td>10.32.35.157:542558</td><td style="text-align: right;">         256</td><td style="text-align: right;">        96</td><td style="text-align: right;">0.000637777</td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">     7</td><td style="text-align: right;">        434.765 </td><td style="text-align: right;">  0.687273</td></tr>
# <tr><td>train_resnet_c80af_00005</td><td>PAUSED    </td><td>10.32.35.157:500827</td><td style="text-align: right;">         256</td><td style="text-align: right;">       112</td><td style="text-align: right;">0.00191392 </td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">    40</td><td style="text-align: right;">        460.809 </td><td style="text-align: right;">  0.745455</td></tr>
# <tr><td>train_resnet_c80af_00006</td><td>PAUSED    </td><td>10.32.35.157:500829</td><td style="text-align: right;">          64</td><td style="text-align: right;">        96</td><td style="text-align: right;">0.000532234</td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">    40</td><td style="text-align: right;">       2881.38  </td><td style="text-align: right;">  0.883636</td></tr>
# <tr><td>train_resnet_c80af_00007</td><td>PAUSED    </td><td>10.32.35.157:500841</td><td style="text-align: right;">         128</td><td style="text-align: right;">        96</td><td style="text-align: right;">0.00126159 </td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">    40</td><td style="text-align: right;">       2792.19  </td><td style="text-align: right;">  0.909091</td></tr>
# <tr><td>train_resnet_c80af_00008</td><td>PAUSED    </td><td>10.32.35.157:500842</td><td style="text-align: right;">         256</td><td style="text-align: right;">        96</td><td style="text-align: right;">0.00014789 </td><td>True       </td><td>rmsprop    </td><td style="text-align: right;">    40</td><td style="text-align: right;">       2948.58  </td><td style="text-align: right;">  0.818182</td></tr>
# <tr><td>train_resnet_c80af_00012</td><td>PAUSED    </td><td>10.32.35.157:500955</td><td style="text-align: right;">          64</td><td style="text-align: right;">       112</td><td style="text-align: right;">0.00111584 </td><td>False      </td><td>r
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name              </th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_resnet_c80af_00000</td><td style="text-align: right;">  0.952727</td></tr>
# <tr><td>train_resnet_c80af_00001</td><td style="text-align: right;">  0.832727</td></tr>
# <tr><td>train_resnet_c80af_00002</td><td style="text-align: right;">  0.509091</td></tr>
# <tr><td>train_resnet_c80af_00003</td><td style="text-align: right;">  0.934545</td></tr>
# <tr><td>train_resnet_c80af_00004</td><td style="text-align: right;">  0.869091</td></tr>
# <tr><td>train_resnet_c80af_00005</td><td style="text-align: right;">  0.745455</td></tr>
# <tr><td>train_resnet_c80af_00006</td><td style="text-align: right;">  0.883636</td></tr>
# <tr><td>train_resnet_c80af_00007</td><td style="text-align: right;">  0.909091</td></tr>
# <tr><td>train_resnet_c80af_00008</td><td style="text-align: right;">  0.818182</td></tr>
# <tr><td>train_resnet_c80af_00009</td><td style="text-align: right;">  0.934545</td></tr>
# <tr><td>train_resnet_c80af_00010</td><td style="text-align: right;">  0.56    </td></tr>
# <tr><td>train_resnet_c80af_00011</td><td style="text-align: right;">  0.643636</td></tr>
# <tr><td>train_resnet_c80af_00012</td><td style="text-align: right;">  0.756364</td></tr>
# <tr><td>train_resnet_c80af_00013</td><td style="text-align: right;">  0.592727</td></tr>
# <tr><td>train_resnet_c80af_00014</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00015</td><td style="text-align: right;">  0.861818</td></tr>
# <tr><td>train_resnet_c80af_00016</td><td style="text-align: right;">  0.934545</td></tr>
# <tr><td>train_resnet_c80af_00017</td><td style="text-align: right;">  0.883636</td></tr>
# <tr><td>train_resnet_c80af_00018</td><td style="text-align: right;">  0.930909</td></tr>
# <tr><td>train_resnet_c80af_00019</td><td style="text-align: right;">  0.734545</td></tr>
# <tr><td>train_resnet_c80af_00020</td><td style="text-align: right;">  0.498182</td></tr>
# <tr><td>train_resnet_c80af_00021</td><td style="text-align: right;">  0.592727</td></tr>
# <tr><td>train_resnet_c80af_00022</td><td style="text-align: right;">  0.610909</td></tr>
# <tr><td>train_resnet_c80af_00023</td><td style="text-align: right;">  0.650909</td></tr>
# <tr><td>train_resnet_c80af_00024</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00025</td><td style="text-align: right;">  0.672727</td></tr>
# <tr><td>train_resnet_c80af_00026</td><td style="text-align: right;">  0.687273</td></tr>
# <tr><td>train_resnet_c80af_00027</td><td style="text-align: right;">  0.56    </td></tr>
# <tr><td>train_resnet_c80af_00028</td><td style="text-align: right;">  0.570909</td></tr>
# <tr><td>train_resnet_c80af_00029</td><td style="text-align: right;">  0.934545</td></tr>
# <tr><td>train_resnet_c80af_00030</td><td style="text-align: right;">  0.818182</td></tr>
# <tr><td>train_resnet_c80af_00031</td><td style="text-align: right;">  0.501818</td></tr>
# <tr><td>train_resnet_c80af_00032</td><td style="text-align: right;">  0.665455</td></tr>
# <tr><td>train_resnet_c80af_00033</td><td style="text-align: right;">  0.865455</td></tr>
# <tr><td>train_resnet_c80af_00034</td><td style="text-align: right;">  0.869091</td></tr>
# <tr><td>train_resnet_c80af_00035</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00036</td><td style="text-align: right;">  0.636364</td></tr>
# <tr><td>train_resnet_c80af_00037</td><td style="text-align: right;">  0.949091</td></tr>
# <tr><td>train_resnet_c80af_00038</td><td style="text-align: right;">  0.665455</td></tr>
# <tr><td>train_resnet_c80af_00039</td><td style="text-align: right;">  0.894545</td></tr>
# <tr><td>train_resnet_c80af_00040</td><td style="text-align: right;">  0.563636</td></tr>
# <tr><td>train_resnet_c80af_00041</td><td style="text-align: right;">  0.934545</td></tr>
# <tr><td>train_resnet_c80af_00042</td><td style="text-align: right;">  0.770909</td></tr>
# <tr><td>train_resnet_c80af_00043</td><td style="text-align: right;">  0.472727</td></tr>
# <tr><td>train_resnet_c80af_00044</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00045</td><td style="text-align: right;">  0.883636</td></tr>
# <tr><td>train_resnet_c80af_00046</td><td style="text-align: right;">  0.523636</td></tr>
# <tr><td>train_resnet_c80af_00047</td><td style="text-align: right;">  0.694545</td></tr>
# <tr><td>train_resnet_c80af_00048</td><td style="text-align: right;">  0.861818</td></tr>
# <tr><td>train_resnet_c80af_00049</td><td style="text-align: right;">  0.538182</td></tr>
# <tr><td>train_resnet_c80af_00050</td><td style="text-align: right;">  0.810909</td></tr>
# <tr><td>train_resnet_c80af_00051</td><td style="text-align: right;">  0.534545</td></tr>
# <tr><td>train_resnet_c80af_00052</td><td style="text-align: right;">  0.930909</td></tr>
# <tr><td>train_resnet_c80af_00053</td><td style="text-align: right;">  0.487273</td></tr>
# <tr><td>train_resnet_c80af_00054</td><td style="text-align: right;">  0.88    </td></tr>
# <tr><td>train_resnet_c80af_00055</td><td style="text-align: right;">  0.938182</td></tr>
# <tr><td>train_resnet_c80af_00056</td><td style="text-align: right;">  0.483636</td></tr>
# <tr><td>train_resnet_c80af_00057</td><td style="text-align: right;">  0.76    </td></tr>
# <tr><td>train_resnet_c80af_00058</td><td style="text-align: right;">  0.912727</td></tr>
# <tr><td>train_resnet_c80af_00059</td><td style="text-align: right;">  0.858182</td></tr>
# <tr><td>train_resnet_c80af_00060</td><td style="text-align: right;">  0.832727</td></tr>
# <tr><td>train_resnet_c80af_00061</td><td style="text-align: right;">  0.832727</td></tr>
# <tr><td>train_resnet_c80af_00062</td><td style="text-align: right;">  0.930909</td></tr>
# <tr><td>train_resnet_c80af_00063</td><td style="text-align: right;">  0.923636</td></tr>
# <tr><td>train_resnet_c80af_00064</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00065</td><td style="text-align: right;">  0.494545</td></tr>
# <tr><td>train_resnet_c80af_00066</td><td style="text-align: right;">  0.916364</td></tr>
# <tr><td>train_resnet_c80af_00067</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00068</td><td style="text-align: right;">  0.494545</td></tr>
# <tr><td>train_resnet_c80af_00069</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00070</td><td style="text-align: right;">  0.872727</td></tr>
# <tr><td>train_resnet_c80af_00071</td><td style="text-align: right;">  0.494545</td></tr>
# <tr><td>train_resnet_c80af_00072</td><td style="text-align: right;">  0.709091</td></tr>
# <tr><td>train_resnet_c80af_00073</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00074</td><td style="text-align: right;">  0.534545</td></tr>
# <tr><td>train_resnet_c80af_00075</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00076</td><td style="text-align: right;">  0.930909</td></tr>
# <tr><td>train_resnet_c80af_00077</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00078</td><td style="text-align: right;">  0.792727</td></tr>
# <tr><td>train_resnet_c80af_00079</td><td style="text-align: right;">  0.494545</td></tr>
# <tr><td>train_resnet_c80af_00080</td><td style="text-align: right;">  0.901818</td></tr>
# <tr><td>train_resnet_c80af_00081</td><td style="text-align: right;">  0.505455</td></tr>
# <tr><td>train_resnet_c80af_00082</td><td style="text-align: right;">  0.494545</td></tr>
# <tr><td>train_resnet_c80af_00083</td><td style="text-align: right;">  0.516364</td></tr>
# <tr><td>train_resnet_c80af_00084</td><td style="text-align: right;">  0.512727</td></tr>
# <tr><td>train_resnet_c80af_00085</td><td style="text-align: right;">  0.523636</td></tr>
# <tr><td>train_resnet_c80af_00086</td><td style="text-align: right;">  0.527273</td></tr>
# <tr><td>train_resnet_c80af_00087</td><td style="text-align: right;">  0.861818<
# 2024-01-05 11:03:36,469	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 1.471 s, which may be a performance bottleneck.
# 2024-01-05 11:03:36,491	WARNING util.py:202 -- The `process_trial_result` operation took 1.492 s, which may be a performance bottleneck.
# 2024-01-05 11:03:36,491	WARNING util.py:202 -- Processing trial results took 1.493 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:03:36,492	WARNING util.py:202 -- The `process_trial_result` operation took 1.493 s, which may be a performance bottleneck.
# 2024-01-05 11:03:39,339	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 1.461 s, which may be a performance bottleneck.
# 2024-01-05 11:03:39,341	WARNING util.py:202 -- The `process_trial_result` operation took 1.463 s, which may be a performance bottleneck.
# 2024-01-05 11:03:39,341	WARNING util.py:202 -- Processing trial results took 1.464 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:03:39,343	WARNING util.py:202 -- The `process_trial_result` operation took 1.466 s, which may be a performance bottleneck.
# 2024-01-05 11:04:09,754	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 1.573 s, which may be a performance bottleneck.
# 2024-01-05 11:04:09,771	WARNING util.py:202 -- The `process_trial_result` operation took 1.590 s, which may be a performance bottleneck.
# 2024-01-05 11:04:09,772	WARNING util.py:202 -- Processing trial results took 1.591 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:04:09,774	WARNING util.py:202 -- The `process_trial_result` operation took 1.593 s, which may be a performance bottleneck.
# 2024-01-05 11:08:54,532	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.904 s, which may be a performance bottleneck.
# 2024-01-05 11:08:54,534	WARNING util.py:202 -- The `process_trial_result` operation took 0.906 s, which may be a performance bottleneck.
# 2024-01-05 11:08:54,535	WARNING util.py:202 -- Processing trial results took 0.907 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:08:54,536	WARNING util.py:202 -- The `process_trial_result` operation took 0.908 s, which may be a performance bottleneck.
# 2024-01-05 11:09:00,817	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 1.809 s, which may be a performance bottleneck.
# 2024-01-05 11:09:00,818	WARNING util.py:202 -- The `process_trial_result` operation took 1.811 s, which may be a performance bottleneck.
# 2024-01-05 11:09:00,819	WARNING util.py:202 -- Processing trial results took 1.811 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:09:00,819	WARNING util.py:202 -- The `process_trial_result` operation took 1.812 s, which may be a performance bottleneck.
# 2024-01-05 11:20:36,715	WARNING util.py:202 -- The `scheduler.on_trial_result` operation took 1.258 s, which may be a performance bottleneck.
# 2024-01-05 11:20:36,783	WARNING util.py:202 -- The `process_trial_result` operation took 1.325 s, which may be a performance bottleneck.
# 2024-01-05 11:20:36,784	WARNING util.py:202 -- Processing trial results took 1.326 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:20:36,784	WARNING util.py:202 -- The `process_trial_result` operation took 1.326 s, which may be a performance bottleneck.
# 2024-01-05 11:37:16,938	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 11:39:42,138	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 11:44:09,684	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 11:44:47,511	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 11:48:10,205	WARNING util.py:202 -- The `scheduler.on_trial_result` operation took 1.393 s, which may be a performance bottleneck.
# 2024-01-05 11:48:10,278	WARNING util.py:202 -- The `process_trial_result` operation took 1.466 s, which may be a performance bottleneck.
# 2024-01-05 11:48:10,279	WARNING util.py:202 -- Processing trial results took 1.467 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:48:10,279	WARNING util.py:202 -- The `process_trial_result` operation took 1.468 s, which may be a performance bottleneck.
# 2024-01-05 11:55:50,734	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 11:57:41,903	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 11:59:23,916	WARNING util.py:202 -- The `scheduler.on_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-01-05 11:59:23,946	WARNING util.py:202 -- The `process_trial_result` operation took 0.553 s, which may be a performance bottleneck.
# 2024-01-05 11:59:23,948	WARNING util.py:202 -- Processing trial results took 0.555 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 11:59:23,948	WARNING util.py:202 -- The `process_trial_result` operation took 0.555 s, which may be a performance bottleneck.
# 2024-01-05 12:00:12,695	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:01:34,819	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:02:20,347	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:03:31,829	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:05:23,946	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:05:59,207	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:08:07,496	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:08:52,345	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:09:22,963	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:09:43,302	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:09:49,422	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:10:25,992	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:11:00,330	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:11:11,392	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:11:23,912	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:11:52,002	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:12:12,577	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:14:25,729	WARNING util.py:202 -- The `scheduler.on_trial_result` operation took 0.629 s, which may be a performance bottleneck.
# 2024-01-05 12:14:25,764	WARNING util.py:202 -- The `process_trial_result` operation took 0.664 s, which may be a performance bottleneck.
# 2024-01-05 12:14:25,783	WARNING util.py:202 -- Processing trial results took 0.682 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 12:14:25,783	WARNING util.py:202 -- The `process_trial_result` operation took 0.683 s, which may be a performance bottleneck.
# 2024-01-05 12:14:49,644	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:15:10,130	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:15:33,082	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:16:48,969	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:17:18,300	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:17:24,831	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:17:36,381	WARNING util.py:202 -- The `scheduler.on_trial_result` operation took 0.598 s, which may be a performance bottleneck.
# 2024-01-05 12:17:36,434	WARNING util.py:202 -- The `process_trial_result` operation took 0.652 s, which may be a performance bottleneck.
# 2024-01-05 12:17:36,449	WARNING util.py:202 -- Processing trial results took 0.666 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 12:17:36,456	WARNING util.py:202 -- The `process_trial_result` operation took 0.674 s, which may be a performance bottleneck.
# 2024-01-05 12:17:49,454	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:17:50,941	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:18:16,375	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:19:20,249	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:19:34,627	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:19:36,557	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:19:41,977	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:20:21,574	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=13; Now=1
# 2024-01-05 12:20:38,684	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:21:40,976	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=13; Now=1
# 2024-01-05 12:22:19,827	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=13; Now=1
# 2024-01-05 12:23:55,628	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=13; Now=1
# 2024-01-05 12:24:13,222	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:26:37,224	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:26:49,355	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:27:23,732	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:27:28,325	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=13; Now=1
# 2024-01-05 12:27:41,641	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:28:30,342	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:28:59,552	WARNING util.py:202 -- The `scheduler.on_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-01-05 12:28:59,587	WARNING util.py:202 -- The `process_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2024-01-05 12:28:59,588	WARNING util.py:202 -- Processing trial results took 0.547 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-01-05 12:28:59,589	WARNING util.py:202 -- The `process_trial_result` operation took 0.548 s, which may be a performance bottleneck.
# 2024-01-05 12:29:01,538	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:29:27,814	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
# 2024-01-05 12:30:08,682	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=1; Now=1
# 2024-01-05 12:30:32,511	INFO hyperband.py:543 -- Restoring from a previous point in time. Previous=4; Now=1
